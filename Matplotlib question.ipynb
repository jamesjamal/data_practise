# %% [markdown]
# # Basic plots with Matplotlib

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Q. Perform a line plot, where x axis value is(1,2,3,5) and y axis value is(2,4,1,3) **(2 mark)**

# %%
## START CODE HERE : 

import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 5],[2,4,1,3])
plt.ylabel('yaxis')
plt.xlabel('xaxis')
plt.show()

## END CODE

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# Q. Perform a scatter plot, where x axis value is(10,35,15,25,50) and y axis vlaue is(1.1,3.5,1.5,2.5,5.0) **(2 mark)**

# %%
## START CODE HERE : 

plt.scatter([10,35,15,25,50],[1.1,3.5,1.5,2.5,5.0])
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.show()

## END CODE

# %% [markdown]
# ## Histogram
#
# > You can use **help(plt.hist)** to know more about the hist function

# %% [markdown]
# Q. Plot a histogram, where values are (20, 45, 75, 90, 100, 105, 130, 145) and keepin the bins as 6. **(2 marks)**

# %%
## START CODE HERE : 

#help(plt.hist)



plt.hist([20, 45, 75, 90, 100, 105, 130, 145], bins= 6 , histtype='bar',width=10
    )

## END CODE
# Out:
# (array([1., 1., 1., 2., 1., 2.]),
#  array([ 20.        ,  40.83333333,  61.66666667,  82.5       ,
#         103.33333333, 124.16666667, 145.        ]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# Solve the following Plot line questions using matplotlib where:
#
# Q1. x axis value is(10, 20, 30, 40) and y axis value is(20, 40, 10, 30)
#
# Q2. Add x , y axis labels stating "x-axis" and "y-axis" respectively.**(1 mark)**
#
# Q3. Add title as "Matplotlib". **(1 mark)**
#
# Q4. Add double ticks in y axis with values (0, 2, 4, 6) **(1 mark)**
#
# Q5. Add another value x = (10, 20, 30, 40) and y = (40, 10, 30, 20) and show it. **(1 mark)**

# %%
## 1. START CODE HERE : 


fig,ax=plt.subplots()

ax.plot([10, 20, 30, 40],[20, 40, 10, 30])

#ax.set_xticks([10, 20, 30, 40])
#ax.set_yticks([20, 40, 10, 30])


## END CODE

## 2. START CODE HERE : 

ax.set_xlabel('xaxis')
ax.set_ylabel('yaxis')

## END CODE

## 3. START CODE HERE : 

ax.set_title('Matplotlib')

## END CODE## 

## 4. START CODE HERE : 

ax1=ax.twinx()

ax1.set_yticks([0, 2, 4, 6])

## END CODE

## 5. START CODE HERE : 

ax.plot([10, 20, 30, 40],[40, 10, 30, 20],color = 'y')

ax1.tick_params(axis='y', labelcolor='r')

## END CODE




plt.show()
